# %% [markdown]
# ## work with ipl one

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %% [markdown]
# ## loading and info

# %%
ipl=pd.read_csv("/home/jai/Desktop/vs project /IPL.csv")
ipl.head(6)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5         6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
# ...

# %%
print("data types",ipl.dtypes)
# Out:
# data types match_id               int64
# date                     str
# venue                    str
# team1                    str
# team2                    str
# stage                    str
# toss_winner              str
# toss_decision            str
# first_ings_score       int64
# first_ings_wkts        int64
# second_ings_score      int64
# second_ings_wkts       int64
# match_winner             str
# won_by                   str
# margin                 int64
# player_of_the_match      str
# top_scorer               str
# highscore              int64
# best_bowling             str
# best_bowling_figure      str
# dtype: object

# %%
print("shape",ipl.shape)
print("info",ipl.info())
# Out:
# shape (74, 20)
# <class 'pandas.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     str
#  2   venue                74 non-null     str
#  3   team1                74 non-null     str
#  4   team2                74 non-null     str
#  5   stage                74 non-null     str
#  6   toss_winner          74 non-null     str
#  7   toss_decision        74 non-null     str
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     str
#  13  won_by               74 non-null     str
#  14  margin               74 non-null     int64
#  15  player_of_the_match  74 non-null     str
# ...

# %%
nullvaluse=ipl.isnull().sum().sort_values(ascending=True)
print("null_ check",nullvaluse)
# Out:
# null_ check match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %% [markdown]
# ## finding the answer of the few qutions by graphs

# %% [markdown]
# which team is win on the ipl mach

# %%
matches=ipl["match_winner"].value_counts()
plotbar= sns.barplot(y=matches.index,x=matches.values,palette="rainbow",)
plt.title("MAM OF THE MATCH")
# Out:
# /tmp/ipykernel_4220/3958343599.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plotbar= sns.barplot(y=matches.index,x=matches.values,palette="rainbow",)
# Text(0.5, 1.0, 'MAM OF THE MATCH')

# %% [markdown]
# On tossing the coin which dessiction is take most

# %%
toss=sns.countplot(x=ipl["toss_decision"],palette="Set2",legend="full")
plt.title('TOSS DECISION')
# Out:
# /tmp/ipykernel_4220/3163526226.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   toss=sns.countplot(x=ipl["toss_decision"],palette="Set2",legend="full")
# Text(0.5, 1.0, 'TOSS DECISION')

# %% [markdown]
# 3) toss winner vs match winner

# %%
df = ipl[ipl['toss_winner'] == ipl['match_winner']]['match_id'].count()
persantage=(df *100)/ipl.shape[0]
persantage=round(persantage,2)
persantage
# Out:
# np.float64(48.65)

# %% [markdown]
# how is the team is win by run vs wicket

# %%
sns.countplot(x=ipl["won_by"])
# Out:
# <Axes: xlabel='won_by', ylabel='count'>

# %% [markdown]
# ## Key Player Performances
# 1.most of the match won by player

# %%
count=ipl['player_of_the_match']
man_count=count.value_counts().head(10)
sns.barplot(x=man_count,y=man_count.index)
# Out:
# <Axes: xlabel='count', ylabel='player_of_the_match'>

# %% [markdown]
# 2. top scores

# %%
top=ipl.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
top.plot(kind=('barh'))
# Out:
# <Axes: ylabel='top_scorer'>

# %% [markdown]
# ##  Venue anliysis
#  the venue where most of the match are played

# %%
df=ipl['venue'].value_counts()
sns.barplot(x=df.values,y=df.index)
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# ## Custom Questions & Insights
# 1)Who won the highest margin by runs?

# %%
ipl[ipl['won_by'] == 'Runs'].sort_values(by='margin',ascending=False).head(1)[["match_winner","margin"]]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# 2)which player has highest individual score

# %%
ipl[ipl["highscore"]==ipl["highscore"].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140
